# %% [markdown]
# # Cleaning , Transformation, and EDA Process

# %% [markdown]
# ### Part 1: Importing the library and the database in csv file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read in the data
#
# > ** The `read_csv` method reads CSV files and accepts many parameters.**

# %%
df = pd.read_csv(r"C:\Private wen\Courses\PORTFOLIO PROJECS\PROJECT 1 DATA CLEANING & TRANSFORMATION\PYTHON\Alzheimer Disease and Healthy Aging Data In US.csv")
# Out:
# C:\Users\wendy\AppData\Local\Temp\ipykernel_35716\3969163797.py:1: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Private wen\Courses\PORTFOLIO PROJECS\PROJECT 1 DATA CLEANING & TRANSFORMATION\PYTHON\Alzheimer Disease and Healthy Aging Data In US.csv")

# %% [markdown]
# ## Exploratory Data Analysis EDA
#
# > ** We nedd to know how looks our data.**

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc Datasource           Class  \
# 0       2020     2020           HI       Hawaii      BRFSS  Overall Health
# 1       2017     2017           ID        Idaho      BRFSS   Mental Health
# 2       2017     2017           ID        Idaho      BRFSS  Overall Health
# 3       2018     2018           ID        Idaho      BRFSS  Overall Health
# 4       2020     2020           IN      Indiana      BRFSS   Mental Health
#
#                                              Topic  \
# 0                     Arthritis among older adults
# 1                 Lifetime diagnosis of depression
# 2                     Arthritis among older adults
# 3  Physically unhealthy days (mean number of days)
# 4                 Lifetime diagnosis of depression
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults ever told they have...               %
# ...

# %%
df.tail()
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 214457       2016     2016           WY      Wyoming      BRFSS
# 214458       2015     2015           WY      Wyoming      BRFSS
# 214459       2017     2017           WY      Wyoming      BRFSS
# 214460       2016     2016           WY      Wyoming      BRFSS
# 214461       2018     2018           WY      Wyoming      BRFSS
#
#                           Class  \
# 214457           Overall Health
# 214458  Smoking and Alcohol Use
# 214459           Overall Health
# 214460           Overall Health
# 214461  Smoking and Alcohol Use
#
#                                                   Topic  \
# 214457  Physically unhealthy days (mean number of days)
# 214458                                  Current smoking
# 214459          Self-rated health (fair to poor health)
# 214460                Fall with injury within last year
# 214461               Binge drinking within past 30 days
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214462 entries, 0 to 214461
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  214462 non-null  int64
#  1   YearEnd                    214462 non-null  int64
#  2   LocationAbbr               214462 non-null  object
#  3   LocationDesc               214462 non-null  object
#  4   Datasource                 214462 non-null  object
#  5   Class                      214462 non-null  object
#  6   Topic                      214462 non-null  object
#  7   Question                   214462 non-null  object
#  8   Data_Value_Unit            214462 non-null  object
#  9   DataValueTypeID            214462 non-null  object
#  10  Data_Value_Type            214462 non-null  object
#  11  Data_Value                 144629 non-null  float64
#  12  Data_Value_Alt             144629 non-null  float64
# ...

# %%
df.describe()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  214462.000000  214462.000000  144629.000000   144629.000000
# mean     2017.378477    2017.634000      37.341956       37.341956
# std         1.779822       1.778926      25.183017       25.183017
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2016.000000    2016.000000      15.300000       15.300000
# 50%      2017.000000    2018.000000      32.500000       32.500000
# 75%      2019.000000    2019.000000      56.800000       56.800000
# max      2020.000000    2020.000000     100.000000      100.000000
#
#        Sample_Size     LocationID
# count          0.0  214462.000000
# mean           NaN     800.987821
# std            NaN    2512.934094
# min            NaN       1.000000
# 25%            NaN      18.000000
# 50%            NaN      33.000000
# 75%            NaN      49.000000
# max            NaN    9004.000000

# %%
df.shape
# Out:
# (214462, 29)

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# Datasource                    object
# Class                         object
# Topic                         object
# Question                      object
# Data_Value_Unit               object
# DataValueTypeID               object
# Data_Value_Type               object
# Data_Value                   float64
# Data_Value_Alt               float64
# Low_Confidence_Limit          object
# High_Confidence_Limit         object
# Sample_Size                  float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2       object
# Stratification2               object
# Geolocation                   object
# ClassID                       object
# TopicID                       object
# QuestionID                    object
# LocationID                     int64
# ...

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit                   0
# DataValueTypeID                   0
# Data_Value_Type                   0
# Data_Value                    69833
# Data_Value_Alt                69833
# Low_Confidence_Limit          69990
# High_Confidence_Limit         69990
# Sample_Size                  214462
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2       27669
# Stratification2               27669
# Geolocation                   23049
# ClassID                           0
# TopicID                           0
# QuestionID                        0
# LocationID                        0
# StratificationCategoryID1         0
# ...

# %%
df.nunique()
# Out:
# YearStart                       6
# YearEnd                         6
# LocationAbbr                   59
# LocationDesc                   59
# Datasource                      1
# Class                           7
# Topic                          39
# Question                       39
# Data_Value_Unit                 2
# DataValueTypeID                 2
# Data_Value_Type                 2
# Data_Value                    999
# Data_Value_Alt                999
# Low_Confidence_Limit         1967
# High_Confidence_Limit        1966
# Sample_Size                     0
# StratificationCategory1         1
# Stratification1                 3
# StratificationCategory2         2
# Stratification2                 7
# Geolocation                    54
# ClassID                         7
# TopicID                        39
# QuestionID                     39
# LocationID                     59
# StratificationCategoryID1       1
# StratificationID1               3
# ...

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'DataValueTypeID',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Alt',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Sample_Size',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID',
#        'LocationID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %%
df.sort_values(by="LocationID", ascending=False).head(5)
# Out:
#         YearStart  YearEnd LocationDesc                                Class  \
# 208796       2015     2015         West                    Cognitive Decline
# 210380       2019     2019         West                    Cognitive Decline
# 201745       2016     2016         West                           Caregiving
# 210368       2016     2016         West                       Overall Health
# 210371       2017     2017         West  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 208796  Functional difficulties associated with subjec...
# 210380  Functional difficulties associated with subjec...
# 201745  Provide care for someone with cognitive impair...
# 210368          Recent activity limitations in past month
# 210371  No leisure-time physical activity within past ...
#
#                                                  Question Data_Value_Unit  \
# 208796  Percentage of older adults who reported subjec...               %
# ...

# %% [markdown]
# ## Cleaning process
#
# > **Now we going to start the cleaning process**

# %%
df
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 0            2020     2020           HI       Hawaii      BRFSS
# 1            2017     2017           ID        Idaho      BRFSS
# 2            2017     2017           ID        Idaho      BRFSS
# 3            2018     2018           ID        Idaho      BRFSS
# 4            2020     2020           IN      Indiana      BRFSS
# ...           ...      ...          ...          ...        ...
# 214457       2016     2016           WY      Wyoming      BRFSS
# 214458       2015     2015           WY      Wyoming      BRFSS
# 214459       2017     2017           WY      Wyoming      BRFSS
# 214460       2016     2016           WY      Wyoming      BRFSS
# 214461       2018     2018           WY      Wyoming      BRFSS
#
#                           Class  \
# 0                Overall Health
# 1                 Mental Health
# 2                Overall Health
# 3                Overall Health
# ...

# %%
df['StratificationID2'].describe()
# Out:
# count      214462
# unique          8
# top       OVERALL
# freq        27669
# Name: StratificationID2, dtype: object

# %%
df['Low_Confidence_Limit'].shape
# Out:
# (214462,)

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationDesc                      0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit                   0
# Data_Value                    69833
# Data_Value_Alt                69833
# Low_Confidence_Limit          69990
# High_Confidence_Limit         69990
# Sample_Size                  214462
# StratificationCategory1           0
# Stratification1                   0
# StratificationCategory2       27669
# Stratification2               27669
# Geolocation                   23049
# ClassID                           0
# TopicID                           0
# QuestionID                        0
# LocationID                        0
# StratificationCategoryID1         0
# StratificationID1                 0
# StratificationCategoryID2         0
# StratificationID2                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value',
#        'Data_Value_Alt', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Sample_Size', 'StratificationCategory1', 'Stratification1',
#        'StratificationCategory2', 'Stratification2', 'Geolocation', 'ClassID',
#        'TopicID', 'QuestionID', 'LocationID', 'StratificationCategoryID1',
#        'StratificationID1', 'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %%
## df = df.drop(columns = "DataValueTypeID")
## df = df.drop(columns = "Data_Value_Type")
## df = df.drop(columns = "LocationAbbr")
## df = df.drop(columns = "Datasource")

df
# Out:
#         YearStart  YearEnd LocationDesc                    Class  \
# 0            2020     2020       Hawaii           Overall Health
# 1            2017     2017        Idaho            Mental Health
# 2            2017     2017        Idaho           Overall Health
# 3            2018     2018        Idaho           Overall Health
# 4            2020     2020      Indiana            Mental Health
# ...           ...      ...          ...                      ...
# 214457       2016     2016      Wyoming           Overall Health
# 214458       2015     2015      Wyoming  Smoking and Alcohol Use
# 214459       2017     2017      Wyoming           Overall Health
# 214460       2016     2016      Wyoming           Overall Health
# 214461       2018     2018      Wyoming  Smoking and Alcohol Use
#
#                                                   Topic  \
# 0                          Arthritis among older adults
# 1                      Lifetime diagnosis of depression
# ...

# %%
## Change  Null values for 0
df = df.fillna(0)
df
# Out:
#         YearStart  YearEnd LocationDesc                    Class  \
# 0            2020     2020       Hawaii           Overall Health
# 1            2017     2017        Idaho            Mental Health
# 2            2017     2017        Idaho           Overall Health
# 3            2018     2018        Idaho           Overall Health
# 4            2020     2020      Indiana            Mental Health
# ...           ...      ...          ...                      ...
# 214457       2016     2016      Wyoming           Overall Health
# 214458       2015     2015      Wyoming  Smoking and Alcohol Use
# 214459       2017     2017      Wyoming           Overall Health
# 214460       2016     2016      Wyoming           Overall Health
# 214461       2018     2018      Wyoming  Smoking and Alcohol Use
#
#                                                   Topic  \
# 0                          Arthritis among older adults
# 1                      Lifetime diagnosis of depression
# ...

# %%
df.isnull().sum()
# Out:
# YearStart                    0
# YearEnd                      0
# LocationDesc                 0
# Class                        0
# Topic                        0
# Question                     0
# Data_Value_Unit              0
# Data_Value                   0
# Data_Value_Alt               0
# Low_Confidence_Limit         0
# High_Confidence_Limit        0
# Sample_Size                  0
# StratificationCategory1      0
# Stratification1              0
# StratificationCategory2      0
# Stratification2              0
# Geolocation                  0
# ClassID                      0
# TopicID                      0
# QuestionID                   0
# LocationID                   0
# StratificationCategoryID1    0
# StratificationID1            0
# StratificationCategoryID2    0
# StratificationID2            0
# dtype: int64

# %% [markdown]
# ## Part 4: Exporting files in csv, and excel.

# %%
df.to_csv(r"C:\Private wen\Courses\PORTFOLIO PROJECS\PROJECT 1 DATA CLEANING & TRANSFORMATION\PYTHON\output\output1.csv")

# %%
df.to_excel(r"C:\Private wen\Courses\PORTFOLIO PROJECS\PROJECT 1 DATA CLEANING & TRANSFORMATION\PYTHON\output\output2.xlsx")
